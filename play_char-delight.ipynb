# %% [markdown]
# ## Train a character-level GPT on some text data
#
# The inputs here are simple text files, which we chop up to individual characters and then train GPT on. So you could say this is a char-transformer instead of a char-rnn. Doesn't quite roll off the tongue as well. In this example we will feed it some shakespear, which we'll get it to predict character-level.

# %%
# set up logging
import logging
logging.basicConfig(
        format="%(asctime)s - %(levelname)s - %(name)s -   %(message)s",
        datefmt="%m/%d/%Y %H:%M:%S",
        level=logging.INFO,
)

# %%
# make deterministic
from mingpt.utils import set_seed
set_seed(42)

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.nn import functional as F

# %%
torch.set_num_threads(4)

# %%
import math
from torch.utils.data import Dataset

class CharDataset(Dataset):

    def __init__(self, data, block_size):
        chars = list(set(data))
        data_size, vocab_size = len(data), len(chars)
        print('data has %d characters, %d unique.' % (data_size, vocab_size))
        
        self.stoi = { ch:i for i,ch in enumerate(chars) }
        self.itos = { i:ch for i,ch in enumerate(chars) }
        self.block_size = block_size
        self.vocab_size = vocab_size
        self.data = data
    
    def __len__(self):
        return math.ceil(len(self.data) / (self.block_size + 1))

    def __getitem__(self, idx):
        # we're actually going to "cheat" and pick a spot in the dataset at random
        i = np.random.randint(0, len(self.data) - (self.block_size + 1))
        chunk = self.data[i:i+self.block_size+1]
        dix = [self.stoi[s] for s in chunk]
        x = torch.tensor(dix[:-1], dtype=torch.long)
        y = torch.tensor(dix[1:], dtype=torch.long)
        return x, y

# %%
block_size = 128 # spatial extent of the model for its context

# %%
# you can download this file at https://github.com/karpathy/char-rnn/blob/master/data/tinyshakespeare/input.txt
text = open('input.txt', 'r').read() # don't worry we won't run out of file handles
train_dataset = CharDataset(text, block_size) # one line of poem is roughly 50 characters
# Out:
# data has 1115394 characters, 65 unique.

# %%
from mingpt.model_delight import DelightConfig, DelightModel
mconf = DelightConfig(
    train_dataset.vocab_size, 
    train_dataset.block_size,
    n_layer=12, n_head=1, 
    n_embd=512
)
model = DelightModel(mconf)
# Out:
# 08/22/2020 04:22:06 - INFO - mingpt.model_delight -   number of parameters: 1.974738e+07

# %%
print(model)
# Out:
# DelightModel(
#   (tok_emb): Embedding(65, 512)
#   (drop): Dropout(p=0.1, inplace=False)
#   (blocks): Sequential(
#     (0): DelightBlock(
#       (dextra_layer): DExTraUnit(
#         (input_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#         (dextra_layers): ModuleList(
#           (0): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (1): GroupLinear(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (2): GroupLinear(
#             (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (3): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#         )
#         (output_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (attn): CausalSelfAttention(
#         (key): Linear(in_features=256, out_features=256, bias=True)
#         (query): Linear(in_features=256, out_features=256, bias=True)
#         (value): Linear(in_features=256, out_features=256, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (resid_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=256, out_features=512, bias=True)
#       )
#       (ln1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=512, out_features=128, bias=True)
#         (1): GELU()
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=128, out_features=512, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#       (ln2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (1): DelightBlock(
#       (dextra_layer): DExTraUnit(
#         (input_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#         (dextra_layers): ModuleList(
#           (0): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (1): GroupLinear(
#             (norm): LayerNorm((268,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (2): GroupLinear(
#             (norm): LayerNorm((268,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (3): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#         )
#         (output_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (attn): CausalSelfAttention(
#         (key): Linear(in_features=256, out_features=256, bias=True)
#         (query): Linear(in_features=256, out_features=256, bias=True)
#         (value): Linear(in_features=256, out_features=256, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (resid_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=256, out_features=512, bias=True)
#       )
#       (ln1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=512, out_features=128, bias=True)
#         (1): GELU()
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=128, out_features=512, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#       (ln2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (2): DelightBlock(
#       (dextra_layer): DExTraUnit(
#         (input_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#         (dextra_layers): ModuleList(
#           (0): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (1): GroupLinear(
#             (norm): LayerNorm((280,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (2): GroupLinear(
#             (norm): LayerNorm((280,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (3): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#         )
#         (output_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (attn): CausalSelfAttention(
#         (key): Linear(in_features=256, out_features=256, bias=True)
#         (query): Linear(in_features=256, out_features=256, bias=True)
#         (value): Linear(in_features=256, out_features=256, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (resid_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=256, out_features=512, bias=True)
#       )
#       (ln1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=512, out_features=128, bias=True)
#         (1): GELU()
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=128, out_features=512, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#       (ln2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (3): DelightBlock(
#       (dextra_layer): DExTraUnit(
#         (input_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#         (dextra_layers): ModuleList(
#           (0): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (1): GroupLinear(
#             (norm): LayerNorm((178,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (2): GroupLinear(
#             (norm): LayerNorm((146,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (3): GroupLinear(
#             (norm): LayerNorm((178,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (4): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#         )
#         (output_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (attn): CausalSelfAttention(
#         (key): Linear(in_features=256, out_features=256, bias=True)
#         (query): Linear(in_features=256, out_features=256, bias=True)
#         (value): Linear(in_features=256, out_features=256, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (resid_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=256, out_features=512, bias=True)
#       )
#       (ln1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=512, out_features=128, bias=True)
#         (1): GELU()
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=128, out_features=512, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#       (ln2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (4): DelightBlock(
#       (dextra_layer): DExTraUnit(
#         (input_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#         (dextra_layers): ModuleList(
#           (0): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (1): GroupLinear(
#             (norm): LayerNorm((184,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (2): GroupLinear(
#             (norm): LayerNorm((152,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (3): GroupLinear(
#             (norm): LayerNorm((184,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (4): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#         )
#         (output_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (attn): CausalSelfAttention(
#         (key): Linear(in_features=256, out_features=256, bias=True)
#         (query): Linear(in_features=256, out_features=256, bias=True)
#         (value): Linear(in_features=256, out_features=256, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (resid_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=256, out_features=512, bias=True)
#       )
#       (ln1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=512, out_features=128, bias=True)
#         (1): GELU()
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=128, out_features=512, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#       (ln2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (5): DelightBlock(
#       (dextra_layer): DExTraUnit(
#         (input_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#         (dextra_layers): ModuleList(
#           (0): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (1): GroupLinear(
#             (norm): LayerNorm((190,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (2): GroupLinear(
#             (norm): LayerNorm((157,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (3): GroupLinear(
#             (norm): LayerNorm((190,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (4): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#         )
#         (output_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (attn): CausalSelfAttention(
#         (key): Linear(in_features=256, out_features=256, bias=True)
#         (query): Linear(in_features=256, out_features=256, bias=True)
#         (value): Linear(in_features=256, out_features=256, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (resid_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=256, out_features=512, bias=True)
#       )
#       (ln1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=512, out_features=128, bias=True)
#         (1): GELU()
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=128, out_features=512, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#       (ln2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (6): DelightBlock(
#       (dextra_layer): DExTraUnit(
#         (input_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#         (dextra_layers): ModuleList(
#           (0): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (1): GroupLinear(
#             (norm): LayerNorm((196,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (2): GroupLinear(
#             (norm): LayerNorm((163,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (3): GroupLinear(
#             (norm): LayerNorm((163,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (4): GroupLinear(
#             (norm): LayerNorm((196,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (5): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#         )
#         (output_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (attn): CausalSelfAttention(
#         (key): Linear(in_features=256, out_features=256, bias=True)
#         (query): Linear(in_features=256, out_features=256, bias=True)
#         (value): Linear(in_features=256, out_features=256, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (resid_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=256, out_features=512, bias=True)
#       )
#       (ln1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=512, out_features=128, bias=True)
#         (1): GELU()
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=128, out_features=512, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#       (ln2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (7): DelightBlock(
#       (dextra_layer): DExTraUnit(
#         (input_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#         (dextra_layers): ModuleList(
#           (0): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (1): GroupLinear(
#             (norm): LayerNorm((202,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (2): GroupLinear(
#             (norm): LayerNorm((169,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (3): GroupLinear(
#             (norm): LayerNorm((169,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (4): GroupLinear(
#             (norm): LayerNorm((202,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (5): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#         )
#         (output_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (attn): CausalSelfAttention(
#         (key): Linear(in_features=256, out_features=256, bias=True)
#         (query): Linear(in_features=256, out_features=256, bias=True)
#         (value): Linear(in_features=256, out_features=256, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (resid_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=256, out_features=512, bias=True)
#       )
#       (ln1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=512, out_features=128, bias=True)
#         (1): GELU()
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=128, out_features=512, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#       (ln2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (8): DelightBlock(
#       (dextra_layer): DExTraUnit(
#         (input_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#         (dextra_layers): ModuleList(
#           (0): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (1): GroupLinear(
#             (norm): LayerNorm((208,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (2): GroupLinear(
#             (norm): LayerNorm((175,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (3): GroupLinear(
#             (norm): LayerNorm((175,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (4): GroupLinear(
#             (norm): LayerNorm((208,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (5): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#         )
#         (output_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (attn): CausalSelfAttention(
#         (key): Linear(in_features=256, out_features=256, bias=True)
#         (query): Linear(in_features=256, out_features=256, bias=True)
#         (value): Linear(in_features=256, out_features=256, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (resid_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=256, out_features=512, bias=True)
#       )
#       (ln1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=512, out_features=128, bias=True)
#         (1): GELU()
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=128, out_features=512, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#       (ln2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (9): DelightBlock(
#       (dextra_layer): DExTraUnit(
#         (input_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#         (dextra_layers): ModuleList(
#           (0): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (1): GroupLinear(
#             (norm): LayerNorm((164,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (2): GroupLinear(
#             (norm): LayerNorm((131,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (3): GroupLinear(
#             (norm): LayerNorm((181,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (4): GroupLinear(
#             (norm): LayerNorm((131,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (5): GroupLinear(
#             (norm): LayerNorm((164,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (6): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#         )
#         (output_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (attn): CausalSelfAttention(
#         (key): Linear(in_features=256, out_features=256, bias=True)
#         (query): Linear(in_features=256, out_features=256, bias=True)
#         (value): Linear(in_features=256, out_features=256, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (resid_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=256, out_features=512, bias=True)
#       )
#       (ln1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=512, out_features=128, bias=True)
#         (1): GELU()
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=128, out_features=512, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#       (ln2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (10): DelightBlock(
#       (dextra_layer): DExTraUnit(
#         (input_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#         (dextra_layers): ModuleList(
#           (0): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (1): GroupLinear(
#             (norm): LayerNorm((168,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (2): GroupLinear(
#             (norm): LayerNorm((135,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (3): GroupLinear(
#             (norm): LayerNorm((187,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (4): GroupLinear(
#             (norm): LayerNorm((135,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (5): GroupLinear(
#             (norm): LayerNorm((168,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (6): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#         )
#         (output_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (attn): CausalSelfAttention(
#         (key): Linear(in_features=256, out_features=256, bias=True)
#         (query): Linear(in_features=256, out_features=256, bias=True)
#         (value): Linear(in_features=256, out_features=256, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (resid_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=256, out_features=512, bias=True)
#       )
#       (ln1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=512, out_features=128, bias=True)
#         (1): GELU()
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=128, out_features=512, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#       (ln2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (11): DelightBlock(
#       (dextra_layer): DExTraUnit(
#         (input_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#         (dextra_layers): ModuleList(
#           (0): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (1): GroupLinear(
#             (norm): LayerNorm((172,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (2): GroupLinear(
#             (norm): LayerNorm((139,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (3): GroupLinear(
#             (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (4): GroupLinear(
#             (norm): LayerNorm((192,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (5): GroupLinear(
#             (norm): LayerNorm((139,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (6): GroupLinear(
#             (norm): LayerNorm((172,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#           (7): GroupLinear(
#             (norm): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#             (act): GELU()
#           )
#         )
#         (output_layer): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (2): GELU()
#           (3): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (attn): CausalSelfAttention(
#         (key): Linear(in_features=256, out_features=256, bias=True)
#         (query): Linear(in_features=256, out_features=256, bias=True)
#         (value): Linear(in_features=256, out_features=256, bias=True)
#         (attn_drop): Dropout(p=0.1, inplace=False)
#         (resid_drop): Dropout(p=0.1, inplace=False)
#         (proj): Linear(in_features=256, out_features=512, bias=True)
#       )
#       (ln1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (mlp): Sequential(
#         (0): Linear(in_features=512, out_features=128, bias=True)
#         (1): GELU()
#         (2): Dropout(p=0.1, inplace=False)
#         (3): Linear(in_features=128, out_features=512, bias=True)
#         (4): Dropout(p=0.1, inplace=False)
#       )
#       (ln2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (ln_f): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   (head): Linear(in_features=512, out_features=65, bias=False)
# )

# %%
from mingpt.trainer import Trainer, TrainerConfig

# initialize a trainer instance and kick off training
tconf = TrainerConfig(max_epochs=200, batch_size=128, learning_rate=3e-4,
                      weight_decay=0, betas=(0.9, 0.98), grad_norm_clip=0.,
                      lr_decay=True, warmup_tokens=512*20, final_tokens=200*len(train_dataset)*block_size,
                      num_workers=4)
trainer = Trainer(model, train_dataset, None, tconf)
trainer.train()
# Out:
# epoch 1 iter 67: train loss 2.50245. lr 2.999818e-04: 100%|██████████| 68/68 [1:32:57<00:00, 82.02s/it]
# epoch 2 iter 67: train loss 2.39625. lr 2.999267e-04: 100%|██████████| 68/68 [1:33:22<00:00, 82.38s/it]
# epoch 3 iter 64: train loss 2.31426. lr 2.998386e-04:  96%|█████████▌| 65/68 [1:32:57<04:42, 94.10s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-4dbfdbc5c2cf> in <module>
#       7                       num_workers=4)
#       8 trainer = Trainer(model, train_dataset, None, tconf)
# ----> 9 trainer.train()
#
# ~/Documents/Samples/minGPT/mingpt/trainer.py in train(self)
#     126         for epoch in range(config.max_epochs):
#     127
# --> 128             run_epoch('train')
#     129             if self.test_dataset is not None:
#     130                 run_epoch('test')
#
# ~/Documents/Samples/minGPT/mingpt/trainer.py in run_epoch(split)
#      94                     # backprop and update the parameters
#      95                     model.zero_grad()
# ---> 96                     loss.backward()
#      97
#      98                     if config.grad_norm_clip > 0:
#
# ~/.conda/envs/ai/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     183                 products. Defaults to ``False``.
#     184         """
# --> 185         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     186
#     187     def register_hook(self, hook):
#
# ~/.conda/envs/ai/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     125     Variable._execution_engine.run_backward(
#     126         tensors, grad_tensors, retain_graph, create_graph,
# --> 127         allow_unreachable=True)  # allow_unreachable flag
#     128
#     129
#
# KeyboardInterrupt:

# %%
# alright, let's sample some character-level shakespear
from mingpt.utils import sample

context = "O God, O God!"
x = torch.tensor([train_dataset.stoi[s] for s in context], dtype=torch.long)[None,...].to(trainer.device)
y = sample(model, x, 2000, temperature=0.9, sample=True, top_k=5)[0]
completion = ''.join([train_dataset.itos[int(i)] for i in y])
print(completion)
# Out:
# O God, O God! I my bar stond thath sthous, ten mon man theresthis.
#
#
# LIUCHES:
#
#
# And bothen me wo she hare shonge than sh bere mar thing.
#
#
# CANAUS:
# I, t hanor t we hand sorar m aneat thit tit bean ar stint ten and theall
# Wiss s brothor tirersthe t se this ther toond tis har tind at ar monom t shoff tor bere beat be s oorour. tint.
#
# WIOLO:
# I bowhin wheld buth s manont m mar tof thand tir be tinghes be se thofrsthot.
#
# SSAULO:
# I bowin t wind, we tear when howell thend tingr beeng serom,
# An t tiorind bun thant thir thind te t stooures m atong t soreris,
# Wind thal blis borite bare st aint athest, bountin t torerst tis anot.
#
#
# SCHANS:
# I, soul wallll,-wert mer wit blaing te and ar tore st ofon ar and
# And storent mer maim bene and bend athand sin seandeng teeas,
# Whor bend thow bet sthing bere torister hest seand,
# Itere that stont seen thours tors meere ars siound beant
#
# Th sthare wer he st hathe the meald tis seast antir ben be siseat t ond.
#
#
# CHERORDY:
# A blouterd t his her thit thou s toul tom thealll m,
# Tore witil therere t theate mit te hinous minds hon ben mis thar athalll s toure my.
#
#
# LLARETARO:
# And, wanth tor wel the stind hatent til timer t soomes are mis.
#
#
# PELO:
# The weren misis bear t ate thast sthin ther,
# An wor benthat se ant tour blordist he the mant meait ban s,
# Andist thand bait the t sinon the thath t thomal meal s at t thathare thime t seates
#
# Ant, wowhor we wheat bout breris tis hand sherist he mand theand,
# And t broust ait d thise hinting thiss hat sthour s seealler,
#
# Thend meatil t boute blinte be sthint thiss mar me mor tissthen t mant,
# An sindit man d mis ble the tount m tante as tin bristithint
#
# Tho t hat hilis hower heng t areas s seathat tharst,
# And ther wat tound, that tist sthille meat the thind ant mat bend sthind sther tim.
#
#
# ANGLO:
# I wanou t, thow the theand, bo myowe wathind thirs bere heand t atent s thanom alll
#
# Ancke towe t thinder that this thit shit mer shathal t s thimanghas t tor tound
# Thin ble seas, toung t sheant t te anderth st as aithe thisthis s

# %%
# well that was fun
